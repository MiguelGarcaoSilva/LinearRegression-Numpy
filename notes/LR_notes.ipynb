# %% [markdown]
# # Linear Regression Model
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Note: Alternative way to find the best parameters
#
# The parameters of the linear regression can be computed in one go, without iterations, using the "Normal equation", solving the Ordinary Least Squares, but its slower for very high dimension data.
